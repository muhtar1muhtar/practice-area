# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = pd.read_csv('/Users/muhtarmuhtar/Documents/vscode-projects/csv/UKMacroData.csv')
df['year'] = df['Date'].str[:4]
df['quarter'] = df['Date'].str[-2:]
df.head()
# Out:
#       Date  GDP (£ m)  CPI  Bank Rate  \
# 0  2000 Q1     401242  1.1      5.875
# 1  2000 Q2     404196  1.0      6.000
# 2  2000 Q3     406795  1.2      6.000
# 3  2000 Q4     409411  1.4      6.000
# 4  2001 Q1     413054  1.3      5.750
#
#    Gross Fixed Capital Formation (Investments)  year quarter
# 0                                      69114.0  2000      Q1
# 1                                      73074.0  2000      Q2
# 2                                      68011.0  2000      Q3
# 3                                      70115.0  2000      Q4
# 4                                      70186.0  2001      Q1

# %%
df_pivot = pd.pivot_table(data=df, index='year', columns='quarter', values='GDP (£ m)')
df_pivot
# Out:
# quarter        Q1        Q2        Q3        Q4
# year
# 2000     401242.0  404196.0  406795.0  409411.0
# 2001     413054.0  414878.0  417085.0  418445.0
# 2002     419534.0  421587.0  424425.0  427725.0
# 2003     430832.0  434837.0  438710.0  442172.0
# 2004     443853.0  446443.0  448171.0  450464.0
# 2005     453784.0  457557.0  461135.0  465451.0
# 2006     467840.0  469655.0  470918.0  473372.0
# 2007     477823.0  481314.0  484544.0  487413.0
# 2008     489783.0  487386.0  479872.0  469694.0
# 2009     460105.0  458599.0  458875.0  460238.0
# 2010     464543.0  469606.0  472199.0  472612.0
# 2011     473819.0  474365.0  475813.0  476479.0
# 2012     480632.0  479979.0  484579.0  484039.0
# 2013     485409.0  488930.0  493002.0  496466.0
# 2014     500552.0  504939.0  508741.0  512334.0
# 2015     513850.0  516876.0  518915.0  521920.0
# 2016     523813.0  526750.0  528712.0  532082.0
# 2017     536566.0  540020.0  543452.0  547377.0
# 2018     547688.0  548600.0  550425.0  551128.0
# 2019     555141.0  556932.0  560987.0  560861.0
# 2020     545597.0  434718.0  507643.0  514531.0
# 2021     509261.0  546579.0  555956.0  564407.0
# 2022     567396.0  567889.0  567445.0  568034.0
# 2023     569336.0  569364.0  568655.0  566695.0

# %%
fig, axes = plt.subplots(figsize=(10,7))
sns.heatmap(data=df_pivot, annot=True, linewidths=.5, cmap='icefire')
plt.show()

# %%
fig, axes = plt.subplots(figsize=(10,7))
sns.heatmap(data=df_pivot, annot=True, fmt=".0f", linewidths=.5, cmap='icefire')
plt.show()

# %% [markdown]
# # Line Plot
#
# A line plot displays information as a series of data points in a two-dimensional chart - x and y-axis. Line plots are fundamental for visualising data trends over time (time series) or ordered categories. They can be used to track changes over intervals, highlighting trends, growth, or cycles in the data.
#
#     When to Use: Ideal for any time series analysis, or when data needs to be displayed as a continuous curve to show trends. This is perhaps the most direct method for observing how variables evolve over time or through a sequence.
#     Example Application: Frequently used in economic data analysis like tracking stock prices, GDP growth over years, or in science to plot changes in temperature, population growth, or similar metrics over time.
#     It allows you to see the relationship between variables

# %%
np.random.seed(seed=1)
x= np.linspace(start=0,stop=10,num=50)
df = pd.DataFrame(data={"Demand":np.random.randn(50) + 5,
                        "Margin":np.sin(3*x),
                        "UserClicks":15 + np.cos(2*x) * x,
})

df.head(3)
# Out:
#      Demand    Margin  UserClicks
# 0  6.624345  0.000000   15.000000
# 1  4.388244  0.574706   15.187317
# 2  4.471828  0.940633   15.279552

# %%
fig, axes = plt.subplots(figsize=(10,5))
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# # Categorical Plot
# A categorical plot is a type of data visualisation that displays the relationship between a categorical variable and one or more numerical variables. It is used to summarise and compare the distribution of data across different categories.
#
#     When to Use: Ideal for comparing distributions, means, or counts across different categories. Useful when you want to understand how a numerical variable varies with respect to a categorical variable.
#     Example Application: Commonly used in surveys, market research, and social sciences to compare responses across different demographic groups or categories.

# %%
df_practice = sns.load_dataset('tips')
df_practice = df_practice.sample(n=50, random_state=1)
df_practice.head(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
sns.displot(df_practice, x='time', hue='day', multiple='stack')
plt.show()

# %%
sns.countplot(data=df_practice, x="time", hue='day')
plt.show()
