# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/muhtarmuhtar/Documents/vscode-projects/UKMacroData.csv')
df
# Out:
#        Date  GDP (£ m)  CPI  Bank Rate  \
# 0   2000 Q1     401242  1.1      5.875
# 1   2000 Q2     404196  1.0      6.000
# 2   2000 Q3     406795  1.2      6.000
# 3   2000 Q4     409411  1.4      6.000
# 4   2001 Q1     413054  1.3      5.750
# ..      ...        ...  ...        ...
# 91  2022 Q4     568034  9.4      3.250
# 92  2023 Q1     569336  9.0      4.125
# 93  2023 Q2     569364  7.7      4.750
# 94  2023 Q3     568655  6.3      5.250
# 95  2023 Q4     566695  4.4      5.250
#
#     Gross Fixed Capital Formation (Investments)
# 0                                       69114.0
# 1                                       73074.0
# 2                                       68011.0
# 3                                       70115.0
# 4                                       70186.0
# ..                                          ...
# 91                                     106689.0
# 92                                     109290.0
# 93                                     108245.0
# ...

# %%
df = pd.read_csv('/Users/muhtarmuhtar/Documents/vscode-projects/UKMacroData.csv', index_col=['Date'])
df
# Out:
#          GDP (£ m)  CPI  Bank Rate  \
# Date
# 2000 Q1     401242  1.1      5.875
# 2000 Q2     404196  1.0      6.000
# 2000 Q3     406795  1.2      6.000
# 2000 Q4     409411  1.4      6.000
# 2001 Q1     413054  1.3      5.750
# ...            ...  ...        ...
# 2022 Q4     568034  9.4      3.250
# 2023 Q1     569336  9.0      4.125
# 2023 Q2     569364  7.7      4.750
# 2023 Q3     568655  6.3      5.250
# 2023 Q4     566695  4.4      5.250
#
#          Gross Fixed Capital Formation (Investments)
# Date
# 2000 Q1                                      69114.0
# 2000 Q2                                      73074.0
# 2000 Q3                                      68011.0
# 2000 Q4                                      70115.0
# 2001 Q1                                      70186.0
# ...                                              ...
# 2022 Q4                                     106689.0
# 2023 Q1                                     109290.0
# ...

# %%
ls
# Out:
# csv_example.csv       test-pd3.ipynb        test-pd7.ipynb
# practice_example.csv  test-pd4.ipynb        test-pd8.ipynb
# test-pd1.ipynb        test-pd5.ipynb        test-pd9.ipynb
# test-pd2.ipynb        test-pd6.ipynb

# %%
df.to_csv('csv_example.csv')

# %%
df_example = pd.read_csv('csv_example.csv')
df_example          # Displaying the DataFrame after reading from the CSV file
# Out:
#        Date  GDP (£ m)  CPI  Bank Rate  \
# 0   2000 Q1     401242  1.1      5.875
# 1   2000 Q2     404196  1.0      6.000
# 2   2000 Q3     406795  1.2      6.000
# 3   2000 Q4     409411  1.4      6.000
# 4   2001 Q1     413054  1.3      5.750
# ..      ...        ...  ...        ...
# 91  2022 Q4     568034  9.4      3.250
# 92  2023 Q1     569336  9.0      4.125
# 93  2023 Q2     569364  7.7      4.750
# 94  2023 Q3     568655  6.3      5.250
# 95  2023 Q4     566695  4.4      5.250
#
#     Gross Fixed Capital Formation (Investments)
# 0                                       69114.0
# 1                                       73074.0
# 2                                       68011.0
# 3                                       70115.0
# 4                                       70186.0
# ..                                          ...
# 91                                     106689.0
# 92                                     109290.0
# 93                                     108245.0
# ...

# %%
df_example = pd.read_csv('csv_example.csv', index_col=['Date'])
df_example          # Displaying the DataFrame after reading from the CSV file with index_col
# Out:
#          GDP (£ m)  CPI  Bank Rate  \
# Date
# 2000 Q1     401242  1.1      5.875
# 2000 Q2     404196  1.0      6.000
# 2000 Q3     406795  1.2      6.000
# 2000 Q4     409411  1.4      6.000
# 2001 Q1     413054  1.3      5.750
# ...            ...  ...        ...
# 2022 Q4     568034  9.4      3.250
# 2023 Q1     569336  9.0      4.125
# 2023 Q2     569364  7.7      4.750
# 2023 Q3     568655  6.3      5.250
# 2023 Q4     566695  4.4      5.250
#
#          Gross Fixed Capital Formation (Investments)
# Date
# 2000 Q1                                      69114.0
# 2000 Q2                                      73074.0
# 2000 Q3                                      68011.0
# 2000 Q4                                      70115.0
# 2001 Q1                                      70186.0
# ...                                              ...
# 2022 Q4                                     106689.0
# 2023 Q1                                     109290.0
# ...

# %%
df = pd.read_csv('/Users/muhtarmuhtar/Documents/vscode-projects/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.to_csv('practice_example.csv')

# %%
search = pd.read_html('https://en.wikipedia.org/wiki/FIFA_World_Cup')
search
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
